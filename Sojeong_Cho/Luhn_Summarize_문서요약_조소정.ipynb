# %% [markdown]
# <a href="https://colab.research.google.com/github/Sjing2/TIL/blob/master/Sojeong_Cho/Luhn_Summarize_%EB%AC%B8%EC%84%9C%EC%9A%94%EC%95%BD_%EC%A1%B0%EC%86%8C%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 1.3MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/bb/7c/99d51f80f3b77b107ebae2634108717362c059a41384a1810d13e2429a81/tweepy-3.9.0-py2.py3-none-any.whl
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 5.3MB/s
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/50/49/725710351d78d26c65337b1e3b322d7b27b34b704535ab56afc0d9ab0ffd/JPype1-1.0.1-cp36-cp36m-manylinux2010_x86_64.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 45.6MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.18.5)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.6.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Installing collected packages: colorama, tweepy, beautifulsoup4, JPype1, konlpy
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.0.1 beautifulsoup4-4.6.0 colorama-0.4.3 konlpy-0.5.2 tweepy-3.9.0

# %%
import numpy as np
from konlpy.tag import Okt

# %%
text_N = len(text)
text_N
# Out:
# 1121

# %%
kkma= Kkma()

text = """ 코로나19 대응 의료 인공지능 컨소시엄 출범 산학연병 인공지능 전문가 20여 명으로 구성, 기술‧응용 공동 연구
지난 8일, 창립준비 모임…미영상의학회 COVID-19 컨소시엄과도 협력

코로나19 바이러스의 세계적 감염 유행에 효과적으로 대응하기 위해 관련 전문가들이 모인 ‘코로나19 감염 대응을 위한 의료 인공지능 컨소시엄’이 9월 1일에 출범한다. 

연세대 의대, 한국전자통신원, 네이버 등 산학연병 20여 명이 참여하는 컨소시엄에서는 인공지능 기술과 응용 분야를 공동으로 연구하고 개발, 검증할 예정이다. 또 이 인공지능 기술을 적용하기 위해 필요한 데이터를 수집, 공유, 활용한다. 나아가 다양한 산학연병 전문가들이 국내외적으로 협력하고 공동으로 대응해 나갈 예정이다.
 
컨소시엄에는 15개 기관의 20여 명 전문가들이 참여했다. 연세대 의과대학에서는 박유랑(의생명시스템정보학), 김휘영(방사선의과학연구소), 심규원(신경외과), 염준섭(감염내과), 최병욱(영상의학과, 사진), 허진(영상의학과) 교수가 참여했다.

대학군에서는 권인호(동아대), 김남국(울산대), 김윤현(전남대), 김진영(계명대), 박상준(서울대), 신수용(성균관대), 정명진(성균관대), 진광남(서울대), 홍헬렌(서울여대) 교수가 , 산업군에서는 김기환(루닛), 이동훈(카카오), 정규환(뷰노), 최우식(딥노이드), 최정필(코어라인소프트), 하정우(네이버)가 기업을 대표해 동참했다.

이 밖에도 전종홍(한국전자통신연구원), 김경훈(정보통신정책연구원), 예종철(한국과학기술원) 교수도 포함됐다.
 
인공지능 컨소시엄은 지난 7월 8일에 창립 준비 위원 모임을 했고, 연세대 의대 영상의학과 최병욱 교수(사진)가 준비위원장으로 선출됐다.

컨소시엄은 북미영상의학회에서 시작한 COVID-19 RICORD 컨소시엄, 유럽연합에서 시작한 COVID-19 이미징 AI 이니셔티브 등과 함께 국제 협력 활동을 펼칠 계획이며, 코로나19 대응을 위한 AI 핵심표준 개발도 목표로 하고 있다. 아울러 대한의료인공지능학회, 대한영상의학회 등 국내 관련 학회와도 적극 협력할 계획이다.
 
한편 오는 7월 24일(금)에는 온라인 워크숍을 개최해 코로나 19 감염대응 의료 인공지능 관련 동향발표 및 연구개발 사례 소개가 있을 예정이다."""

# %%
okt= Okt()
okt_tokens = okt.morphs(text)
okt_tokens
# Out:
# ['코로나',
#  '19',
#  '대응',
#  '의료',
#  '인공',
#  '지능',
#  '컨소시엄',
#  '출범',
#  '산학',
#  '연병',
#  '인공',
#  '지능',
#  '전문가',
#  '20',
#  '여',
#  '명',
#  '으로',
#  '구성',
#  ',',
#  '기술',
#  '‧',
#  '응용',
#  '공동',
#  '연구',
#  '\n',
#  '지난',
#  '8일',
#  ',',
#  '창립',
#  '준비',
#  '모임',
#  '…',
#  '미영',
#  '상의',
#  '학회',
#  'COVID',
#  '-',
#  '19',
#  '컨소시엄',
#  '과도',
#  '협력',
#  '\n\n',
#  '코로나',
#  '19',
#  '바이러스',
#  '의',
#  '세계',
#  '적',
#  '감염',
#  '유행',
#  '에',
#  '효과',
#  '적',
#  '으로',
#  '대응',
#  '하기',
#  '위해',
#  '관련',
#  '전문가',
#  '들',
#  '이',
#  '모인',
#  '‘',
#  '코로나',
#  '19',
#  '감염',
#  '대응',
#  '을',
#  '위',
#  '한',
#  '의료',
#  '인공',
#  '지능',
#  '컨소시엄',
#  '’',
#  '이',
#  '9월',
#  '1일',
#  '에',
#  '출범',
#  '한다',
#  '.',
#  '연세대',
#  '의대',
#  ',',
#  '한국',
#  '전자통신',
#  '원',
#  ',',
#  '네이버',
#  '등',
#  '산학',
#  '연병',
#  '20',
#  '여',
#  '명',
#  '이',
#  '참여',
#  '하는',
#  '컨소시엄',
#  '에서는',
#  '인공',
#  '지능',
#  '기술',
#  '과',
#  '응용',
#  '분야',
#  '를',
#  '공동',
#  '으로',
#  '연구',
#  '하고',
#  '개발',
#  ',',
#  '검증',
#  '할',
#  '예정',
#  '이다',
#  '.',
#  '또',
#  '이',
#  '인공',
#  '지능',
#  '기술',
#  '을',
#  '적용',
#  '하기',
#  '위해',
#  '필요한',
#  '데이터',
#  '를',
#  '수집',
#  ',',
#  '공유',
#  ',',
#  '활용',
#  '한다',
#  '.',
#  '나아가',
#  '다양한',
#  '산학',
#  '연병',
#  '전문가',
#  '들',
#  '이',
#  '국내외',
#  '적',
#  '으로',
#  '협력',
#  '하고',
#  '공동',
#  '으로',
#  '대응',
#  '해',
#  '나갈',
#  '예정',
#  '이다',
#  '.',
#  '\n \n',
#  '컨소시엄',
#  '에는',
#  '15',
#  '개',
#  '기관',
#  '의',
#  '20',
#  '여',
#  '명',
#  '전문가',
#  '들',
#  '이',
#  '참여',
#  '했다',
#  '.',
#  '연세대',
#  '의과대학',
#  '에서는',
#  '박',
#  '유랑',
#  '(',
#  '의',
#  '생명',
#  '시스템',
#  '정보',
#  '학',
#  '),',
#  '김휘영',
#  '(',
#  '방사선',
#  '의과학',
#  '연구소',
#  '),',
#  '심',
#  '규원',
#  '(',
#  '신경',
#  '외과',
#  '),',
#  '염준섭',
#  '(',
#  '감염',
#  '내과',
#  '),',
#  '최병욱',
#  '(',
#  '영상의학',
#  '과',
#  ',',
#  '사진',
#  '),',
#  '허진',
#  '(',
#  '영상의학',
#  '과',
#  ')',
#  '교수',
#  '가',
#  '참여',
#  '했다',
#  '.',
#  '\n\n',
#  '대학',
#  '군',
#  '에서는',
#  '권',
#  '인호',
#  '(',
#  '동아대',
#  '),',
#  '김',
#  '남국',
#  '(',
#  '울산',
#  '대',
#  '),',
#  '김윤현',
#  '(',
#  '전남대',
#  '),',
#  '김진영',
#  '(',
#  '계명대',
#  '),',
#  '박상준',
#  '(',
#  '서울대',
#  '),',
#  '신',
#  '수용',
#  '(',
#  '성균관대',
#  '),',
#  '정명',
#  '진',
#  '(',
#  '성균관대',
#  '),',
#  '진',
#  '광남',
#  '(',
#  '서울대',
#  '),',
#  '홍',
#  '헬렌',
#  '(',
#  '서울',
#  '여대',
#  ')',
#  '교수',
#  '가',
#  ',',
#  '산업',
#  '군',
#  '에서는',
#  '김기환',
#  '(',
#  '루닛',
#  '),',
#  '이동훈',
#  '(',
#  '카카오',
#  '),',
#  '정규환',
#  '(',
#  '뷰노',
#  '),',
#  '최우식',
#  '(',
#  '딥노',
#  '이드',
#  '),',
#  '최정',
#  '필',
#  '(',
#  '코어',
#  '라인',
#  '소프트',
#  '),',
#  '하정우',
#  '(',
#  '네이버',
#  ')',
#  '가',
#  '기업',
#  '을',
#  '대표',
#  '해',
#  '동참',
#  '했다',
#  '.',
#  '\n\n',
#  '이',
#  '밖에도',
#  '전종',
#  '홍',
#  '(',
#  '한국',
#  '전자통신',
#  '연구원',
#  '),',
#  '김경훈',
#  '(',
#  '정보통',
#  '신',
#  '정책',
#  '연구원',
#  '),',
#  '예종',
#  '철',
#  '(',
#  '한국',
#  '과학기술원',
#  ')',
#  '교수',
#  '도',
#  '포함',
#  '됐다',
#  '.',
#  '\n \n',
#  '인공',
#  '지능',
#  '컨소시엄',
#  '은',
#  '지난',
#  '7월',
#  '8일',
#  '에',
#  '창립',
#  '준비',
#  '위원',
#  '모임',
#  '을',
#  '했고',
#  ',',
#  '연세대',
#  '의대',
#  '영상의학',
#  '과',
#  '최병욱',
#  '교수',
#  '(',
#  '사진',
#  ')',
#  '가',
#  '준비',
#  '위원장',
#  '으로',
#  '선출',
#  '됐다',
#  '.',
#  '\n\n',
#  '컨소시엄',
#  '은',
#  '북미',
#  '영상의학',
#  '회',
#  '에서',
#  '시작',
#  '한',
#  'COVID',
#  '-',
#  '19',
#  'RICORD',
#  '컨소시엄',
#  ',',
#  '유럽연합',
#  '에서',
#  '시작',
#  '한',
#  'COVID',
#  '-',
#  '19',
#  '이미',
#  '징',
#  'AI',
#  '이니셔티브',
#  '등',
#  '과',
#  '함께',
#  '국제',
#  '협력',
#  '활동',
#  '을',
#  '펼칠',
#  '계획',
#  '이며',
#  ',',
#  '코로나',
#  '19',
#  '대응',
#  '을',
#  '위',
#  '한',
#  'AI',
#  '핵심',
#  '표준',
#  '개발',
#  '도',
#  '목표',
#  '로',
#  '하고',
#  '있다',
#  '.',
#  '아울러',
#  '대',
#  '한',
#  '의료인',
#  '공',
#  '지능',
#  '학회',
#  ',',
#  '대',
#  '한',
#  '영상의학',
#  '회',
#  '등',
#  '국내',
#  '관련',
#  '학회',
#  '와도',
#  '적극',
#  '협력',
#  '할',
#  '계획',
#  '이다',
#  '.',
#  '\n \n',
#  '한편',
#  '오는',
#  '7월',
#  '24일',
#  '(',
#  '금',
#  ')',
#  '에는',
#  '온라인',
#  '워크숍',
#  '을',
#  '개최',
#  '해',
#  '코로나',
#  '19',
#  '감염',
#  '대응',
#  '의료',
#  '인공',
#  '지능',
#  '관련',
#  '동향',
#  '발표',
#  '및',
#  '연구개발',
#  '사례',
#  '소개',
#  '가',
#  '있을',
#  '예정',
#  '이다',
#  '.']

# %%
word = set(okt_tokens)
FRE = {}

for i in word:
    FRE[i] = okt_tokens.count(i)
FRE
# Out:
# {'\n\n': 3,
#  '\n \n': 2,
#  '(': 25,
#  ')': 5,
#  '),': 20,
#  ',': 12,
#  '-': 1,
#  '.': 11,
#  '15': 1,
#  '19': 8,
#  '1일': 1,
#  '20': 3,
#  '24일': 1,
#  '7월': 2,
#  '8일': 2,
#  '9월': 1,
#  'AI': 2,
#  'COVID': 3,
#  'RICORD': 1,
#  '가': 5,
#  '감염': 4,
#  '개': 1,
#  '개발': 2,
#  '개최': 1,
#  '검증': 1,
#  '계명대': 1,
#  '계획': 2,
#  '공': 1,
#  '공동': 3,
#  '공유': 1,
#  '과': 4,
#  '과도': 1,
#  '과학기술원': 1,
#  '관련': 3,
#  '광남': 1,
#  '교수': 4,
#  '구성': 1,
#  '국내': 1,
#  '국내외': 1,
#  '국제': 1,
#  '군': 2,
#  '권': 1,
#  '규원': 1,
#  '금': 1,
#  '기관': 1,
#  '기술': 3,
#  '기업': 1,
#  '김': 1,
#  '김경훈': 1,
#  '김기환': 1,
#  '김윤현': 1,
#  '김진영': 1,
#  '김휘영': 1,
#  '나갈': 1,
#  '남국': 1,
#  '내과': 1,
#  '네이버': 2,
#  '다양한': 1,
#  '대': 3,
#  '대응': 6,
#  '대표': 1,
#  '대학': 1,
#  '데이터': 1,
#  '도': 2,
#  '동아대': 1,
#  '동참': 1,
#  '동향': 1,
#  '됐다': 2,
#  '들': 2,
#  '등': 2,
#  '딥노': 1,
#  '라인': 1,
#  '로': 1,
#  '루닛': 1,
#  '를': 1,
#  '명': 1,
#  '모인': 1,
#  '모임': 2,
#  '목표': 1,
#  '미영': 1,
#  '및': 1,
#  '바이러스': 1,
#  '박': 1,
#  '박상준': 1,
#  '밖에도': 1,
#  '발표': 1,
#  '방사선': 1,
#  '북미': 1,
#  '분야': 1,
#  '뷰노': 1,
#  '사례': 1,
#  '사진': 2,
#  '산업': 1,
#  '산학': 3,
#  '상의': 1,
#  '생명': 1,
#  '서울': 1,
#  '서울대': 2,
#  '선출': 1,
#  '성균관대': 2,
#  '세계': 1,
#  '소개': 1,
#  '소프트': 1,
#  '수용': 1,
#  '수집': 1,
#  '시스템': 1,
#  '시작': 2,
#  '신': 2,
#  '신경': 1,
#  '심': 1,
#  '아울러': 1,
#  '에': 2,
#  '에는': 1,
#  '에서': 2,
#  '에서는': 3,
#  '여대': 1,
#  '연구': 2,
#  '연구개발': 1,
#  '연구소': 1,
#  '연구원': 2,
#  '연병': 3,
#  '연세대': 3,
#  '염준섭': 1,
#  '영상의학': 5,
#  '예정': 3,
#  '예종': 1,
#  '오는': 1,
#  '온라인': 1,
#  '와도': 1,
#  '외과': 1,
#  '울산': 1,
#  '워크숍': 1,
#  '위': 1,
#  '위원': 1,
#  '위원장': 1,
#  '위해': 1,
#  '유랑': 1,
#  '유럽연합': 1,
#  '유행': 1,
#  '으로': 5,
#  '은': 2,
#  '을': 6,
#  '응용': 2,
#  '의': 1,
#  '의과대학': 1,
#  '의과학': 1,
#  '의대': 2,
#  '의료': 3,
#  '의료인': 1,
#  '이': 4,
#  '이니셔티브': 1,
#  '이다': 3,
#  '이동훈': 1,
#  '이드': 1,
#  '이며': 1,
#  '이미': 1,
#  '인공': 7,
#  '인호': 1,
#  '있다': 1,
#  '있을': 1,
#  '적': 1,
#  '적극': 1,
#  '적용': 1,
#  '전남대': 1,
#  '전문가': 4,
#  '전자통신': 2,
#  '전종': 1,
#  '정규환': 1,
#  '정명': 1,
#  '정보': 1,
#  '정보통': 1,
#  '정책': 1,
#  '준비': 3,
#  '지난': 2,
#  '지능': 8,
#  '진': 2,
#  '징': 1,
#  '참여': 3,
#  '창립': 2,
#  '철': 1,
#  '최병욱': 2,
#  '최우식': 1,
#  '최정': 1,
#  '출범': 2,
#  '카카오': 1,
#  '컨소시엄': 8,
#  '코로나': 5,
#  '코어': 1,
#  '펼칠': 1,
#  '포함': 1,
#  '표준': 1,
#  '필': 1,
#  '필요한': 1,
#  '하고': 3,
#  '하기': 1,
#  '하는': 1,
#  '하정우': 1,
#  '학': 1,
#  '학회': 3,
#  '한': 5,
#  '한국': 3,
#  '한다': 1,
#  '한편': 1,
#  '할': 1,
#  '함께': 1,
#  '해': 2,
#  '핵심': 1,
#  '했고': 1,
#  '했다': 3,
#  '허진': 1,
#  '헬렌': 1,
#  '협력': 4,
#  '홍': 2,
#  '활동': 1,
#  '활용': 1,
#  '회': 2,
#  '효과': 1}

# %%
total = sum((FRE).values())
keywords = []
for a, b in FRE.items():
    if 0.005 < b/total < 0.45:
        keywords.append(a)

# %%
print(keywords)
# Out:
# ['관련', '교수', '학회', '예정', '지능', 'COVID', '영상의학', '협력', '전문가', '공동', '기술', '대응', '인공', '연세대', '했다', '의료', '감염', '하고', '20', '참여', '산학', '준비', '컨소시엄', '),', '연병', '19', '코로나', '한국']

# %%
keywords.remove('),')
keywords
# Out:
# ['관련',
#  '교수',
#  '학회',
#  '예정',
#  '지능',
#  'COVID',
#  '영상의학',
#  '협력',
#  '전문가',
#  '공동',
#  '기술',
#  '대응',
#  '인공',
#  '연세대',
#  '했다',
#  '의료',
#  '감염',
#  '하고',
#  '20',
#  '참여',
#  '산학',
#  '준비',
#  '컨소시엄',
#  '연병',
#  '19',
#  '코로나',
#  '한국']

# %%
X_1 = text.split('.')
X_1 = [x.strip() for x in X_1]

# %%
X_1
# Out:
# ['코로나19 대응 의료 인공지능 컨소시엄 출범 산학연병 인공지능 전문가 20여 명으로 구성, 기술‧응용 공동 연구\n지난 8일, 창립준비 모임…미영상의학회 COVID-19 컨소시엄과도 협력\n\n코로나19 바이러스의 세계적 감염 유행에 효과적으로 대응하기 위해 관련 전문가들이 모인 ‘코로나19 감염 대응을 위한 의료 인공지능 컨소시엄’이 9월 1일에 출범한다',
#  '연세대 의대, 한국전자통신원, 네이버 등 산학연병 20여 명이 참여하는 컨소시엄에서는 인공지능 기술과 응용 분야를 공동으로 연구하고 개발, 검증할 예정이다',
#  '또 이 인공지능 기술을 적용하기 위해 필요한 데이터를 수집, 공유, 활용한다',
#  '나아가 다양한 산학연병 전문가들이 국내외적으로 협력하고 공동으로 대응해 나갈 예정이다',
#  '컨소시엄에는 15개 기관의 20여 명 전문가들이 참여했다',
#  '연세대 의과대학에서는 박유랑(의생명시스템정보학), 김휘영(방사선의과학연구소), 심규원(신경외과), 염준섭(감염내과), 최병욱(영상의학과, 사진), 허진(영상의학과) 교수가 참여했다',
#  '대학군에서는 권인호(동아대), 김남국(울산대), 김윤현(전남대), 김진영(계명대), 박상준(서울대), 신수용(성균관대), 정명진(성균관대), 진광남(서울대), 홍헬렌(서울여대) 교수가 , 산업군에서는 김기환(루닛), 이동훈(카카오), 정규환(뷰노), 최우식(딥노이드), 최정필(코어라인소프트), 하정우(네이버)가 기업을 대표해 동참했다',
#  '이 밖에도 전종홍(한국전자통신연구원), 김경훈(정보통신정책연구원), 예종철(한국과학기술원) 교수도 포함됐다',
#  '인공지능 컨소시엄은 지난 7월 8일에 창립 준비 위원 모임을 했고, 연세대 의대 영상의학과 최병욱 교수(사진)가 준비위원장으로 선출됐다',
#  '컨소시엄은 북미영상의학회에서 시작한 COVID-19 RICORD 컨소시엄, 유럽연합에서 시작한 COVID-19 이미징 AI 이니셔티브 등과 함께 국제 협력 활동을 펼칠 계획이며, 코로나19 대응을 위한 AI 핵심표준 개발도 목표로 하고 있다',
#  '아울러 대한의료인공지능학회, 대한영상의학회 등 국내 관련 학회와도 적극 협력할 계획이다',
#  '한편 오는 7월 24일(금)에는 온라인 워크숍을 개최해 코로나 19 감염대응 의료 인공지능 관련 동향발표 및 연구개발 사례 소개가 있을 예정이다',
#  '']

# %%
X_dic = {}
for o in X_1:
    if o:
        S_tokens = okt.morphs(o)
        S_kw_dic = {}
        for idx, token in enumerate(S_tokens):
            if token in keywords:
                S_kw_dic[token] = idx

        start = min(s_kw_dic.values())
        end = max(S_kw_dic.values())

        word_num = end-start+1
        kw_num = len(S_kw_dic)
        S_sig = kw_num**2/word_num
        X_dic[o] = S_sig

# %%
X_dic
# Out:
# {'나아가 다양한 산학연병 전문가들이 국내외적으로 협력하고 공동으로 대응해 나갈 예정이다': 12.8,
#  '대학군에서는 권인호(동아대), 김남국(울산대), 김윤현(전남대), 김진영(계명대), 박상준(서울대), 신수용(성균관대), 정명진(성균관대), 진광남(서울대), 홍헬렌(서울여대) 교수가 , 산업군에서는 김기환(루닛), 이동훈(카카오), 정규환(뷰노), 최우식(딥노이드), 최정필(코어라인소프트), 하정우(네이버)가 기업을 대표해 동참했다': 0.05333333333333334,
#  '또 이 인공지능 기술을 적용하기 위해 필요한 데이터를 수집, 공유, 활용한다': -1.125,
#  '아울러 대한의료인공지능학회, 대한영상의학회 등 국내 관련 학회와도 적극 협력할 계획이다': 4.166666666666667,
#  '연세대 의과대학에서는 박유랑(의생명시스템정보학), 김휘영(방사선의과학연구소), 심규원(신경외과), 염준섭(감염내과), 최병욱(영상의학과, 사진), 허진(영상의학과) 교수가 참여했다': 1.125,
#  '연세대 의대, 한국전자통신원, 네이버 등 산학연병 20여 명이 참여하는 컨소시엄에서는 인공지능 기술과 응용 분야를 공동으로 연구하고 개발, 검증할 예정이다': 7.681818181818182,
#  '이 밖에도 전종홍(한국전자통신연구원), 김경훈(정보통신정책연구원), 예종철(한국과학기술원) 교수도 포함됐다': 0.4,
#  '인공지능 컨소시엄은 지난 7월 8일에 창립 준비 위원 모임을 했고, 연세대 의대 영상의학과 최병욱 교수(사진)가 준비위원장으로 선출됐다': 3.769230769230769,
#  '컨소시엄에는 15개 기관의 20여 명 전문가들이 참여했다': 25.0,
#  '컨소시엄은 북미영상의학회에서 시작한 COVID-19 RICORD 컨소시엄, 유럽연합에서 시작한 COVID-19 이미징 AI 이니셔티브 등과 함께 국제 협력 활동을 펼칠 계획이며, 코로나19 대응을 위한 AI 핵심표준 개발도 목표로 하고 있다': 1.7297297297297298,
#  '코로나19 대응 의료 인공지능 컨소시엄 출범 산학연병 인공지능 전문가 20여 명으로 구성, 기술‧응용 공동 연구\n지난 8일, 창립준비 모임…미영상의학회 COVID-19 컨소시엄과도 협력\n\n코로나19 바이러스의 세계적 감염 유행에 효과적으로 대응하기 위해 관련 전문가들이 모인 ‘코로나19 감염 대응을 위한 의료 인공지능 컨소시엄’이 9월 1일에 출범한다': 5.918032786885246,
#  '한편 오는 7월 24일(금)에는 온라인 워크숍을 개최해 코로나 19 감염대응 의료 인공지능 관련 동향발표 및 연구개발 사례 소개가 있을 예정이다': 4.764705882352941}

# %%
SS_lst = list(X_dic.items())
SS_lst.sort(key=lambda x: x[1], reverse=True)

# %%
SS_lst
# Out:
# [('컨소시엄에는 15개 기관의 20여 명 전문가들이 참여했다', 25.0),
#  ('나아가 다양한 산학연병 전문가들이 국내외적으로 협력하고 공동으로 대응해 나갈 예정이다', 12.8),
#  ('연세대 의대, 한국전자통신원, 네이버 등 산학연병 20여 명이 참여하는 컨소시엄에서는 인공지능 기술과 응용 분야를 공동으로 연구하고 개발, 검증할 예정이다',
#   7.681818181818182),
#  ('코로나19 대응 의료 인공지능 컨소시엄 출범 산학연병 인공지능 전문가 20여 명으로 구성, 기술‧응용 공동 연구\n지난 8일, 창립준비 모임…미영상의학회 COVID-19 컨소시엄과도 협력\n\n코로나19 바이러스의 세계적 감염 유행에 효과적으로 대응하기 위해 관련 전문가들이 모인 ‘코로나19 감염 대응을 위한 의료 인공지능 컨소시엄’이 9월 1일에 출범한다',
#   5.918032786885246),
#  ('한편 오는 7월 24일(금)에는 온라인 워크숍을 개최해 코로나 19 감염대응 의료 인공지능 관련 동향발표 및 연구개발 사례 소개가 있을 예정이다',
#   4.764705882352941),
#  ('아울러 대한의료인공지능학회, 대한영상의학회 등 국내 관련 학회와도 적극 협력할 계획이다', 4.166666666666667),
#  ('인공지능 컨소시엄은 지난 7월 8일에 창립 준비 위원 모임을 했고, 연세대 의대 영상의학과 최병욱 교수(사진)가 준비위원장으로 선출됐다',
#   3.769230769230769),
#  ('컨소시엄은 북미영상의학회에서 시작한 COVID-19 RICORD 컨소시엄, 유럽연합에서 시작한 COVID-19 이미징 AI 이니셔티브 등과 함께 국제 협력 활동을 펼칠 계획이며, 코로나19 대응을 위한 AI 핵심표준 개발도 목표로 하고 있다',
#   1.7297297297297298),
#  ('연세대 의과대학에서는 박유랑(의생명시스템정보학), 김휘영(방사선의과학연구소), 심규원(신경외과), 염준섭(감염내과), 최병욱(영상의학과, 사진), 허진(영상의학과) 교수가 참여했다',
#   1.125),
#  ('이 밖에도 전종홍(한국전자통신연구원), 김경훈(정보통신정책연구원), 예종철(한국과학기술원) 교수도 포함됐다', 0.4),
#  ('대학군에서는 권인호(동아대), 김남국(울산대), 김윤현(전남대), 김진영(계명대), 박상준(서울대), 신수용(성균관대), 정명진(성균관대), 진광남(서울대), 홍헬렌(서울여대) 교수가 , 산업군에서는 김기환(루닛), 이동훈(카카오), 정규환(뷰노), 최우식(딥노이드), 최정필(코어라인소프트), 하정우(네이버)가 기업을 대표해 동참했다',
#   0.05333333333333334),
#  ('또 이 인공지능 기술을 적용하기 위해 필요한 데이터를 수집, 공유, 활용한다', -1.125)]

# %%
SS_lst[:3]
# Out:
# [('컨소시엄에는 15개 기관의 20여 명 전문가들이 참여했다', 25.0),
#  ('나아가 다양한 산학연병 전문가들이 국내외적으로 협력하고 공동으로 대응해 나갈 예정이다', 12.8),
#  ('연세대 의대, 한국전자통신원, 네이버 등 산학연병 20여 명이 참여하는 컨소시엄에서는 인공지능 기술과 응용 분야를 공동으로 연구하고 개발, 검증할 예정이다',
#   7.681818181818182)]
